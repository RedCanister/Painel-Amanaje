# %%
from app.models.model_registry import ModelRegistry
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import app
#       2 from app.models.model_registry import ModelRegistry
#
# ModuleNotFoundError: No module named 'app'
